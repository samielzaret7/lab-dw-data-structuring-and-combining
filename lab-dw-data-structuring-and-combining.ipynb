# %% [markdown]
# # Lab | Data Structuring and Combining Data

# %% [markdown]
# ## Challenge 1: Combining & Cleaning Data
#
# In this challenge, we will be working with the customer data from an insurance company, as we did in the two previous labs. The data can be found here:
# - https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file1.csv
#
# But this time, we got new data, which can be found in the following 2 CSV files located at the links below.
#
# - https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file2.csv
# - https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file3.csv
#
# Note that you'll need to clean and format the new data.
#
# Observation:
# - One option is to first combine the three datasets and then apply the cleaning function to the new combined dataset
# - Another option would be to read the clean file you saved in the previous lab, and just clean the two new files and concatenate the three clean datasets

# %%
import pandas as pd
pd.set_option('display.max_columns', 50)
df1 = pd.read_csv('https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file1.csv')
df2 = pd.read_csv('https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file2.csv')
df3 = pd.read_csv('https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file3.csv')

# %%
pd.concat([df1,df2,df3])
# Out:
#      Customer          ST GENDER             Education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 7065  LA72316         NaN    NaN              Bachelor
# 7066  PK87824         NaN    NaN               College
# 7067  TD14365         NaN    NaN              Bachelor
# 7068  UP19263         NaN    NaN               College
# 7069  Y167826         NaN    NaN               College
#
#      Customer Lifetime Value   Income  Monthly Premium Auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %%
import pandas as pd
df1 = pd.read_csv('https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file1.csv')
df2 = pd.read_csv('https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file2.csv')
df3 = pd.read_csv('https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file3.csv').rename(columns = {'State':'ST','Gender':'GENDER'})

# %%
df = pd.concat([df1,df2,df3])
df
# Out:
#      Customer          ST GENDER             Education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 7065  LA72316  California      M              Bachelor
# 7066  PK87824  California      F               College
# 7067  TD14365  California      M              Bachelor
# 7068  UP19263  California      M               College
# 7069  Y167826  California      M               College
#
#      Customer Lifetime Value   Income  Monthly Premium Auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %%
from pipeline_functions import whole_pipeline
df = whole_pipeline(df)

# %%
df
# Out:
#      customer       state gender             education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 7065  LA72316  California      M              Bachelor
# 7066  PK87824  California      F               College
# 7067  TD14365  California      M              Bachelor
# 7068  UP19263  California      M               College
# 7069  Y167826  California      M               College
#
#       customer_lifetime_value_%   income  monthly_premium_auto  \
# 0                           NaN      0.0                1000.0
# 1                     697953.59      0.0                  94.0
# 2                    1288743.17  48767.0                 108.0
# ...

# %%
import pandas as pd
df1 = pd.read_csv('https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file1.csv')
df2 = pd.read_csv('https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file2.csv')
df3 = pd.read_csv('https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file3.csv')

# %%
df1 = whole_pipeline(df1)
df2 = whole_pipeline(df2)
df3 = whole_pipeline(df3)

# %%
df = pd.concat([df1,df2,df3])
df.duplicated().sum()
# Out:
# 3

# %% [markdown]
# # Challenge 2: Structuring Data

# %% [markdown]
# In this challenge, we will continue to work with customer data from an insurance company, but we will use a dataset with more columns, called marketing_customer_analysis.csv, which can be found at the following link:
#
# https://raw.githubusercontent.com/data-bootcamp-v4/data/main/marketing_customer_analysis_clean.csv
#
# This dataset contains information such as customer demographics, policy details, vehicle information, and the customer's response to the last marketing campaign. Our goal is to explore and analyze this data by performing data cleaning, formatting, and structuring.

# %%
# Your code goes here
df_customers = pd.read_csv('https://raw.githubusercontent.com/data-bootcamp-v4/data/main/marketing_customer_analysis_clean.csv')
df_customers.set_index('unnamed:_0')
df_customers.drop(columns= 'unnamed:_0')
# Out:
#       customer       state  customer_lifetime_value response  coverage  \
# 0      DK49336     Arizona              4809.216960       No     Basic
# 1      KX64629  California              2228.525238       No     Basic
# 2      LZ68649  Washington             14947.917300       No     Basic
# 3      XL78013      Oregon             22332.439460      Yes  Extended
# 4      QA50777      Oregon              9025.067525       No   Premium
# ...        ...         ...                      ...      ...       ...
# 10905  FE99816      Nevada             15563.369440       No   Premium
# 10906  KX53892      Oregon              5259.444853       No     Basic
# 10907  TL39050     Arizona             23893.304100       No  Extended
# 10908  WA60547  California             11971.977650       No   Premium
# 10909  IV32877  California              6857.519928       No     Basic
#
#       education effective_to_date employmentstatus gender  income  \
# ...

# %%
df_customers = pd.read_csv('https://raw.githubusercontent.com/data-bootcamp-v4/data/main/marketing_customer_analysis_clean.csv',index_col=0)
df_customers.head()
df_customers = pd.read_csv('https://raw.githubusercontent.com/data-bootcamp-v4/data/main/marketing_customer_analysis_clean.csv',usecols=list(range(1,27)))
df_customers.head()
# Out:
#   customer       state  customer_lifetime_value response  coverage education  \
# 0  DK49336     Arizona              4809.216960       No     Basic   College
# 1  KX64629  California              2228.525238       No     Basic   College
# 2  LZ68649  Washington             14947.917300       No     Basic  Bachelor
# 3  XL78013      Oregon             22332.439460      Yes  Extended   College
# 4  QA50777      Oregon              9025.067525       No   Premium  Bachelor
#
#   effective_to_date employmentstatus gender  income location_code  \
# 0        2011-02-18         Employed      M   48029      Suburban
# 1        2011-01-18       Unemployed      F       0      Suburban
# 2        2011-02-10         Employed      M   22139      Suburban
# 3        2011-01-11         Employed      M   49078      Suburban
# 4        2011-01-17    Medical Leave      F   23675      Suburban
#
#   marital_status  monthly_premium_auto  months_since_last_claim  \
# ...

# %%
df_customers.columns
# Out:
# Index(['customer', 'state', 'customer_lifetime_value', 'response', 'coverage',
#        'education', 'effective_to_date', 'employmentstatus', 'gender',
#        'income', 'location_code', 'marital_status', 'monthly_premium_auto',
#        'months_since_last_claim', 'months_since_policy_inception',
#        'number_of_open_complaints', 'number_of_policies', 'policy_type',
#        'policy', 'renew_offer_type', 'sales_channel', 'total_claim_amount',
#        'vehicle_class', 'vehicle_size', 'vehicle_type', 'month'],
#       dtype='object')

# %%
df_customers['total_revenue'] = df_customers['monthly_premium_auto']*df_customers['months_since_policy_inception']*df_customers['number_of_policies']

# %%
pd.pivot_table(df_customers,index='sales_channel',values='customer_lifetime_value',aggfunc='sum').round(2)
pd.pivot_table(df_customers,index='sales_channel',values='monthly_premium_auto',aggfunc='sum').round(2)
pd.pivot_table(df_customers,index='sales_channel',values='total_revenue',aggfunc='sum').round(2)
# Out:
#                total_revenue
# sales_channel
# Agent               53903710
# Branch              40082086
# Call Center         27235765
# Web                 23720513

# %%
df_customers.groupby('sales_channel')[['total_revenue']].sum().round(2)
# Out:
#                total_revenue
# sales_channel
# Agent               53903710
# Branch              40082086
# Call Center         27235765
# Web                 23720513

# %%
df_customers.columns
# Out:
# Index(['customer', 'state', 'customer_lifetime_value', 'response', 'coverage',
#        'education', 'effective_to_date', 'employmentstatus', 'gender',
#        'income', 'location_code', 'marital_status', 'monthly_premium_auto',
#        'months_since_last_claim', 'months_since_policy_inception',
#        'number_of_open_complaints', 'number_of_policies', 'policy_type',
#        'policy', 'renew_offer_type', 'sales_channel', 'total_claim_amount',
#        'vehicle_class', 'vehicle_size', 'vehicle_type', 'month',
#        'total_revenue'],
#       dtype='object')

# %%
pd.pivot_table(df_customers,index='gender',columns='education',values='customer_lifetime_value',aggfunc='mean').round(2)
# Out:
# education  Bachelor  College   Doctor  High School or Below   Master
# gender
# F           7874.27  7748.82  7328.51               8675.22  8157.05
# M           7703.60  8052.46  7415.33               8149.69  8168.83

# %% [markdown]
# 1. You work at the marketing department and you want to know which sales channel brought the most sales in terms of total revenue. Using pivot, create a summary table showing the total revenue for each sales channel (branch, call center, web, and mail).
# Round the total revenue to 2 decimal points.  Analyze the resulting table to draw insights.

# %% [markdown]
# 2. Create a pivot table that shows the average customer lifetime value per gender and education level. Analyze the resulting table to draw insights.

# %% [markdown]
# ## Bonus
#
# You work at the customer service department and you want to know which months had the highest number of complaints by policy type category. Create a summary table showing the number of complaints by policy type and month.
# Show it in a long format table.

# %% [markdown]
# *In data analysis, a long format table is a way of structuring data in which each observation or measurement is stored in a separate row of the table. The key characteristic of a long format table is that each column represents a single variable, and each row represents a single observation of that variable.*
#
# *More information about long and wide format tables here: https://www.statology.org/long-vs-wide-data/*

# %%
df_customers
# Out:
#       customer       state  customer_lifetime_value response  coverage  \
# 0      DK49336     Arizona              4809.216960       No     Basic
# 1      KX64629  California              2228.525238       No     Basic
# 2      LZ68649  Washington             14947.917300       No     Basic
# 3      XL78013      Oregon             22332.439460      Yes  Extended
# 4      QA50777      Oregon              9025.067525       No   Premium
# ...        ...         ...                      ...      ...       ...
# 10905  FE99816      Nevada             15563.369440       No   Premium
# 10906  KX53892      Oregon              5259.444853       No     Basic
# 10907  TL39050     Arizona             23893.304100       No  Extended
# 10908  WA60547  California             11971.977650       No   Premium
# 10909  IV32877  California              6857.519928       No     Basic
#
#       education effective_to_date employmentstatus gender  income  \
# ...

# %%
sorted(df_customers.columns)
# Out:
# ['coverage',
#  'customer',
#  'customer_lifetime_value',
#  'education',
#  'effective_to_date',
#  'employmentstatus',
#  'gender',
#  'income',
#  'location_code',
#  'marital_status',
#  'month',
#  'monthly_premium_auto',
#  'months_since_last_claim',
#  'months_since_policy_inception',
#  'number_of_open_complaints',
#  'number_of_policies',
#  'policy',
#  'policy_type',
#  'renew_offer_type',
#  'response',
#  'sales_channel',
#  'state',
#  'total_claim_amount',
#  'total_revenue',
#  'vehicle_class',
#  'vehicle_size',
#  'vehicle_type']

# %%
df_melt = df_customers.melt(id_vars=['policy_type','number_of_open_complaints'],value_vars=['month'],var_name='month', value_name='Amount')

# %%
df_customers[['policy_type','number_of_open_complaints','month']]
# Out:
#           policy_type  number_of_open_complaints  month
# 0      Corporate Auto                   0.000000      2
# 1       Personal Auto                   0.000000      1
# 2       Personal Auto                   0.000000      2
# 3      Corporate Auto                   0.000000      1
# 4       Personal Auto                   0.384256      1
# ...               ...                        ...    ...
# 10905   Personal Auto                   0.384256      1
# 10906   Personal Auto                   0.000000      1
# 10907  Corporate Auto                   0.000000      2
# 10908   Personal Auto                   4.000000      2
# 10909   Personal Auto                   0.000000      1
#
# [10910 rows x 3 columns]

# %%
df_melt
# Out:
#           policy_type  number_of_open_complaints  month  Amount
# 0      Corporate Auto                   0.000000  month       2
# 1       Personal Auto                   0.000000  month       1
# 2       Personal Auto                   0.000000  month       2
# 3      Corporate Auto                   0.000000  month       1
# 4       Personal Auto                   0.384256  month       1
# ...               ...                        ...    ...     ...
# 10905   Personal Auto                   0.384256  month       1
# 10906   Personal Auto                   0.000000  month       1
# 10907  Corporate Auto                   0.000000  month       2
# 10908   Personal Auto                   4.000000  month       2
# 10909   Personal Auto                   0.000000  month       1
#
# [10910 rows x 4 columns]

# %%
pd.pivot_table(df_customers,index='policy_type',columns='month',values='number_of_open_complaints',aggfunc='sum') #wide
# Out:
# month                     1            2
# policy_type
# Corporate Auto   443.434952   385.208135
# Personal Auto   1727.605722  1453.684441
# Special Auto      87.074049    95.226817

# %%
pd.pivot_table(df_customers,index=['policy_type','month'],values='number_of_open_complaints',aggfunc='sum') #long
# Out:
#                       number_of_open_complaints
# policy_type    month
# Corporate Auto 1                     443.434952
#                2                     385.208135
# Personal Auto  1                    1727.605722
#                2                    1453.684441
# Special Auto   1                      87.074049
#                2                      95.226817
